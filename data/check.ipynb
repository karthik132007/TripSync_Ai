# %%
import pandas as pd

# %%
df = pd.read_json("./africa.json")

# %%
df
# Out:
#                             place       country  \
# 0                       Cape Town  South Africa
# 1            Kruger National Park  South Africa
# 2                    Garden Route  South Africa
# 3                          Durban  South Africa
# 4                           Cairo         Egypt
# ..                            ...           ...
# 131               Augrabies Falls  South Africa
# 132  Kgalagadi Transfrontier Park  South Africa
# 133                          Saly       Senegal
# 134                 Lake Bunyonyi        Uganda
# 135                        Asmara       Eritrea
#
#                                                   tags  avg_cost_per_day  \
# 0    [culture, nature, beach, mountains, food, nigh...              4000
# 1    [safari, nature, wildlife, adventure, camping,...              4500
# 2    [nature, beach, adventure, forest, lakes, whal...              3500
# 3    [beach, culture, food, nightlife, water-sports...              3000
# ...
