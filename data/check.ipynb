# %%
import pandas as pd

# %%
df = pd.read_json("./africa.json")

# %%
df
# Out:
#                                      place          country  \
# 0                                Cape Town     South Africa
# 1                     Kruger National Park     South Africa
# 2                             Garden Route     South Africa
# 3                                   Durban     South Africa
# 4                                    Cairo            Egypt
# 5                         Pyramids of Giza            Egypt
# 6                                    Luxor            Egypt
# 7                                 Hurghada            Egypt
# 8                                Marrakech          Morocco
# 9                 Sahara Desert (Merzouga)          Morocco
# 10                             Maasai Mara            Kenya
# 11                                 Nairobi            Kenya
# 12                             Diani Beach            Kenya
# 13                 Serengeti National Park         Tanzania
# 14                                Zanzibar         Tanzania
# ...
