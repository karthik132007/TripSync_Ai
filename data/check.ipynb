# %%
import pandas as pd

# %%
df = pd.read_json("./data.json")

# %%
df['popularity'].value_counts()
# Out:
# popularity
# Medium       712
# High         582
# Low          147
# Very High    139
# Offbeat       86
# Emerging       2
# Name: count, dtype: int64
