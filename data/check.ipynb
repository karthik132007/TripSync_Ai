# %%
import pandas as pd

# %%
df = pd.read_json("./hotels.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_json("./hotels.json")
#
# File ~/Documents/Random Shit/.venv/lib/python3.13/site-packages/pandas/io/json/_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File ~/Documents/Random Shit/.venv/lib/python3.13/site-packages/pandas/io/json/_json.py:1014, in JsonReader.read(self)
#    1012         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1013 else:
# -> 1014     obj = self._get_object_parser(self.data)
#    1015 if self.dtype_backend is not lib.no_default:
# ...

# %%
df['place'].duplicated()==True
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1663    False
# 1664    False
# 1665    False
# 1666    False
# 1667    False
# Name: place, Length: 1668, dtype: bool
