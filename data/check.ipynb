# %%
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer

# %%
df = pd.read_json("hotels_processed.json")

# %%
encode = MultiLabelBinarizer()
tags = encode.fit_transform(df['amenities'])
tag_df=pd.DataFrame(tags,columns=encode.classes_)

# %%
tag_df.columns
# Out:
# Index(['24hr_front_desk', 'air_conditioning', 'bar', 'breakfast', 'concierge',
#        'garden', 'gym', 'kitchen', 'laundry', 'non_smoking', 'parking', 'pool',
#        'restaurant', 'spa', 'tv', 'wifi'],
#       dtype='str')
