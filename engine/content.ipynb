# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from db.get_from_db import get_places
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dot
from tensorflow.keras.layers import Input

from tensorflow.keras.losses import MeanSquaredError
# Out:
# 2026-02-20 13:25:50.012664: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-20 13:25:50.073100: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-20 13:25:51.624814: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
places_df = get_places()
places_df=places_df.drop(columns=[0,1])
places=places_df.to_numpy()

# %%
no_of_user_features =None

# %%
user_NN = Sequential([
    Dense(256,activation='relu'),
    Dense(128,activation='relu'),
    Dense(32)
])
place_NN = Sequential([
    Dense(256,activation='relu'),
    Dense(128,activation='relu'),
    Dense(32),
])

# %%
user_input = Input(shape=no_of_user_features)
