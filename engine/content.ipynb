# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from db.get_from_db import get_places
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential

# %%
places_df = get_places()
places_df=places_df.drop(columns=[0,1])
places=places_df.to_numpy()

# %%
places
# Out:
# array([[4.0e+03, 5.0e+00, 0.0e+00, ..., 0.0e+00, 0.0e+00, 0.0e+00],
#        [4.5e+03, 4.0e+00, 0.0e+00, ..., 0.0e+00, 1.0e+00, 0.0e+00],
#        [3.5e+03, 5.0e+00, 1.0e+00, ..., 1.0e+00, 0.0e+00, 0.0e+00],
#        ...,
#        [2.5e+03, 1.0e+00, 0.0e+00, ..., 0.0e+00, 1.0e+00, 0.0e+00],
#        [2.0e+03, 2.0e+00, 0.0e+00, ..., 0.0e+00, 1.0e+00, 0.0e+00],
#        [2.2e+03, 1.0e+00, 0.0e+00, ..., 0.0e+00, 1.0e+00, 0.0e+00]],
#       shape=(1668, 72))
