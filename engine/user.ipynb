# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from db.get_from_db import get_places
import pandas as pd
import numpy as np
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import tensorflow as tf
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dot
from tensorflow.keras.layers import Input
from tensorflow.keras.losses import MeanSquaredError

# %%
norm_weight = np.load("norm_weights.npz")

normalizer = tf.keras.layers.Normalization()
normalizer.build((None, 72))

normalizer.set_weights([
    norm_weight["mean"],
    norm_weight["variance"],
    norm_weight["count"]
])

# %%
model=Sequential([
    normalizer,
    Dense(128,activation='relu'),
    tf.keras.layers.Dropout(0.2),
    Dense(64)
])

# %%
model.save("user_tower.keras")
# Out:
# /home/electron/Documents/GitHub/TripSync_Ai/.myenv/lib/python3.13/site-packages/keras/src/saving/saving_api.py:107: UserWarning: You are saving a model that has not yet been built. It might not contain any weights yet. Consider building the model first by calling it on some data.
#   return saving_lib.save_model(model, filepath)
